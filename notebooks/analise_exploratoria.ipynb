# %% [markdown]
# ### Analise Exploratoria

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sweetviz as sv

df = pd.read_csv("./Global_Youtube_Statistics.csv")

# %% [markdown]
# #### Estrutura Basica dos dados

# %%
pd.DataFrame(df)
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991                Natan por A�     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
#Quantidade de linhas e colunas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %% [markdown]
# #### Valores Faltantes

# %%
#Quais Colunas possuem dados faltantes
print(df.isnull().sum())
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
#Quantidade e porcentagem de valores nulos
print(df.isnull().sum().sort_values(ascending=False) / len(df) * 100)
# Out:
# subscribers_for_last_30_days               33.869347
# Latitude                                   12.361809
# Urban_population                           12.361809
# Longitude                                  12.361809
# Population                                 12.361809
# Gross tertiary education enrollment (%)    12.361809
# Unemployment rate                          12.361809
# Abbreviation                               12.261307
# Country                                    12.261307
# country_rank                               11.658291
# video_views_for_the_last_30_days            5.628141
# category                                    4.623116
# channel_type_rank                           3.316583
# channel_type                                3.015075
# created_month                               0.502513
# created_year                                0.502513
# created_date                                0.502513
# video_views_rank                            0.100503
# ...

# %% [markdown]
# #### Distribuição das Variaveis

# %%
df["Youtuber"].describe()
# Out:
# count          995
# unique         995
# top       T-Series
# freq             1
# Name: Youtuber, dtype: object

# %%
df["subscribers_for_last_30_days"].describe()
# Out:
# count    6.580000e+02
# mean     3.490791e+05
# std      6.143554e+05
# min      1.000000e+00
# 25%      1.000000e+05
# 50%      2.000000e+05
# 75%      4.000000e+05
# max      8.000000e+06
# Name: subscribers_for_last_30_days, dtype: float64

# %%
df["Latitude"].describe()
# Out:
# count    872.000000
# mean      26.632783
# std       20.560533
# min      -38.416097
# 25%       20.593684
# 50%       37.090240
# 75%       37.090240
# max       61.924110
# Name: Latitude, dtype: float64

# %%
df["Population"].describe()
# Out:
# count    8.720000e+02
# mean     4.303873e+08
# std      4.727947e+08
# min      2.025060e+05
# 25%      8.335541e+07
# 50%      3.282395e+08
# 75%      3.282395e+08
# max      1.397715e+09
# Name: Population, dtype: float64

# %%
df["Gross tertiary education enrollment (%)"].describe()
# Out:
# count    872.000000
# mean      63.627752
# std       26.106893
# min        7.600000
# 25%       36.300000
# 50%       68.000000
# 75%       88.200000
# max      113.100000
# Name: Gross tertiary education enrollment (%), dtype: float64

# %%
df["Unemployment rate"].describe()
# Out:
# count    872.000000
# mean       9.279278
# std        4.888354
# min        0.750000
# 25%        5.270000
# 50%        9.365000
# 75%       14.700000
# max       14.720000
# Name: Unemployment rate, dtype: float64

# %%
df["Abbreviation"].describe()
# Out:
# count     873
# unique     49
# top        US
# freq      313
# Name: Abbreviation, dtype: object

# %%
df["Country"].describe()
# Out:
# count               873
# unique               49
# top       United States
# freq                313
# Name: Country, dtype: object

# %%
df["country_rank"].describe()
# Out:
# count     879.000000
# mean      386.053470
# std      1232.244746
# min         1.000000
# 25%        11.000000
# 50%        51.000000
# 75%       123.000000
# max      7741.000000
# Name: country_rank, dtype: float64

# %%
df["video_views_for_the_last_30_days"].describe()
# Out:
# count    9.390000e+02
# mean     1.756103e+08
# std      4.163782e+08
# min      1.000000e+00
# 25%      2.013750e+07
# 50%      6.408500e+07
# 75%      1.688265e+08
# max      6.589000e+09
# Name: video_views_for_the_last_30_days, dtype: float64

# %%
df["category"].describe()
# Out:
# count               949
# unique               18
# top       Entertainment
# freq                241
# Name: category, dtype: object

# %%
df["channel_type_rank"].describe()
# Out:
# count     962.000000
# mean      745.719335
# std      1944.386561
# min         1.000000
# 25%        27.000000
# 50%        65.500000
# 75%       139.750000
# max      7741.000000
# Name: channel_type_rank, dtype: float64

# %%
df["channel_type"].describe()
# Out:
# count               965
# unique               14
# top       Entertainment
# freq                304
# Name: channel_type, dtype: object

# %%
df["created_month"].describe()
# Out:
# count     990
# unique     12
# top       Jan
# freq      101
# Name: created_month, dtype: object

# %%
df["created_year"].describe()
# Out:
# count     990.000000
# mean     2012.630303
# std         4.512503
# min      1970.000000
# 25%      2009.000000
# 50%      2013.000000
# 75%      2016.000000
# max      2022.000000
# Name: created_year, dtype: float64

# %%
df["created_date"].describe()
# Out:
# count    990.000000
# mean      15.746465
# std        8.777520
# min        1.000000
# 25%        8.000000
# 50%       16.000000
# 75%       23.000000
# max       31.000000
# Name: created_date, dtype: float64

# %%
df["video_views_rank"].describe()
# Out:
# count    9.940000e+02
# mean     5.542489e+05
# std      1.362782e+06
# min      1.000000e+00
# 25%      3.230000e+02
# 50%      9.155000e+02
# 75%      3.584500e+03
# max      4.057944e+06
# Name: video_views_rank, dtype: float64

# %%
df["rank"].describe()
# Out:
# count    995.00000
# mean     498.00000
# std      287.37606
# min        1.00000
# 25%      249.50000
# 50%      498.00000
# 75%      746.50000
# max      995.00000
# Name: rank, dtype: float64

# %%
df["Title"].describe()
# Out:
# count                  995
# unique                 992
# top       Like Nastya Vlog
# freq                     2
# Name: Title, dtype: object

# %%
df["uploads"].describe()
# Out:
# count       995.000000
# mean       9187.125628
# std       34151.352254
# min           0.000000
# 25%         194.500000
# 50%         729.000000
# 75%        2667.500000
# max      301308.000000
# Name: uploads, dtype: float64

# %%
df["subscribers"].describe()
# Out:
# count    9.950000e+02
# mean     2.298241e+07
# std      1.752611e+07
# min      1.230000e+07
# 25%      1.450000e+07
# 50%      1.770000e+07
# 75%      2.460000e+07
# max      2.450000e+08
# Name: subscribers, dtype: float64

# %%
df["video views"].describe()
# Out:
# count    9.950000e+02
# mean     1.103954e+10
# std      1.411084e+10
# min      0.000000e+00
# 25%      4.288145e+09
# 50%      7.760820e+09
# 75%      1.355470e+10
# max      2.280000e+11
# Name: video views, dtype: float64

# %%
df["lowest_yearly_earnings"].describe()
# Out:
# count    9.950000e+02
# mean     4.422574e+05
# std      8.612161e+05
# min      0.000000e+00
# 25%      3.265000e+04
# 50%      1.595000e+05
# 75%      4.551000e+05
# max      1.020000e+07
# Name: lowest_yearly_earnings, dtype: float64

# %%
df["highest_yearly_earnings"].describe()
# Out:
# count    9.950000e+02
# mean     7.081814e+06
# std      1.379704e+07
# min      0.000000e+00
# 25%      5.217500e+05
# 50%      2.600000e+06
# 75%      7.300000e+06
# max      1.634000e+08
# Name: highest_yearly_earnings, dtype: float64

# %% [markdown]
# #### Qualidade dos dados

# %%
#Porcentagem de dados nulos por coluna
print("Porcentagem de nulos por coluna: ", df.isnull().sum().sort_values(ascending=False) / len(df) * 100)
# Out:
# Porcentagem de nulos por coluna:  subscribers_for_last_30_days               33.869347
# Latitude                                   12.361809
# Urban_population                           12.361809
# Longitude                                  12.361809
# Population                                 12.361809
# Gross tertiary education enrollment (%)    12.361809
# Unemployment rate                          12.361809
# Abbreviation                               12.261307
# Country                                    12.261307
# country_rank                               11.658291
# video_views_for_the_last_30_days            5.628141
# category                                    4.623116
# channel_type_rank                           3.316583
# channel_type                                3.015075
# created_month                               0.502513
# created_year                                0.502513
# created_date                                0.502513
# ...

# %%
#Numero de dados duplicados
print("Numero de dados duplicados: ", df.duplicated().sum())
# Out:
# Numero de dados duplicados:  0

# %%
df['Youtuber'] = df['Youtuber'].str.strip().str.upper().str.lower()
print(df['Youtuber'])
# Out:
# 0                        t-series
# 1                  youtube movies
# 2                         mrbeast
# 3      cocomelon - nursery rhymes
# 4                       set india
#                   ...
# 990                  natan por a�
# 991      free fire india official
# 992                         panda
# 993                   robtopgames
# 994                  make joke of
# Name: Youtuber, Length: 995, dtype: object

# %%
# Compat: cria numpy.VisibleDeprecationWarning se não existir (NumPy 2.0+)
if not hasattr(np, "VisibleDeprecationWarning"):
    class VisibleDeprecationWarning(DeprecationWarning):
        pass
    np.VisibleDeprecationWarning = VisibleDeprecationWarning


report = sv.analyze(df)
report.show_html("relatorio.html")
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report relatorio.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# #### Distribuição das variaveis

# %%
sns.boxplot(x=df['video views'])
plt.show()
